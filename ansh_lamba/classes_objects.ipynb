# %%
class employee():
    
    company_name = 'XYZ' # NOTE: this is a class variable/attribute
    
    def changes(self,new_company_name):
        employee.company_name = new_company_name    
    
    def __init__(self,emp_name, emp_dept):
        print("This is the constructor of the class")
        self.emp_name = emp_name # NOTE: this is an instance variable/attribute
        self.emp_dept = emp_dept # NOTE: this is an instance variable/attribute

    @staticmethod
    def addition(a,b):
        print(f"The sum of {a} and {b} is {a+b}")

    def info(self):
        print(f"Employee name: {self.emp_name} works for {self.emp_dept} department")

# %%
emp1.addition(10,20)
# Out:
# The sum of 10 and 20 is 30

# %%
emp1 = employee("priya","IT")
emp2 = employee("anil","HR")
# Out:
# This is the constructor of the class
# This is the constructor of the class

# %%
emp1.info()
emp2.company_name = "ABC"
print(emp1.company_name)
print(emp2.company_name)
emp2.info()
# Out:
# Employee name: priya works for IT department
# XYZ
# ABC
# Employee name: anil works for HR department

# %%
employee.company_name = "PQR"
emp1.info()
print(emp1.company_name)
print(emp2.company_name)
# Out:
# Employee name: priya works for IT department
# PQR
# ABC

# %%
emp1.changes("LMN")
print(emp1.company_name)
# Out:
# LMN
