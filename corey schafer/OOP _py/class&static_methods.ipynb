# %%
class DataPipeline:
    default_retries = 3 
    
    def __init__(self,name,source,target,retries):
        self.name=name
        self.source=source
        self.target=target
        self.retries=retries 
        
    # --- Instance Methods (normal) --- 
    def run(self):
        print(f"Running {self.name}: {self.source} -> {self.target}")
    
    # --- class method: alternative constructor from dict---
    @classmethod
    def from_config(cls,config:dict):
