# %%
courses = ['history','math','physics','comp_sci']
print(len(courses))
# Out:
# 4

# %%
print(courses[2])
print(courses[-3])
print(courses[1:3:1])
# Out:
# physics
# math
# ['math', 'physics']

# %%
courses.append('Art')
print(courses)
# Out:
# ['Art', 'history', 'math', 'physics', 'comp_sci', 'Art', 'Art', 'Art', 'Art']

# %%
courses.insert(0,'Art')

# %%
courses_2=['Ant','Edu']

# %%
courses.extend(courses_2)

# %%
print(courses[0])
# Out:
# ['Ant', 'Edu']

# %%
print(courses)
# Out:
# [['Ant', 'Edu'], 'Art', 'history', 'physics', 'comp_sci', 'Art', 'Art', 'Art', 'Art', 'Ant']

# %%
courses.remove('math')

# %%
popped=courses.pop()
print(popped)
# Out:
# Art

# %%
print(courses.reverse())
# Out:
# None

# %%
sorted_courses=sorted(courses)

# %%
print(min(courses))
# Out:
# Art

# %%
for item in enumerate(courses):
    print(item)
# Out:
# (0, ['Ant', 'Edu'])
# (1, 'Art')
# (2, 'history')
# (3, 'physics')
# (4, 'comp_sci')
# (5, 'Art')
# (6, 'Art')
# (7, 'Art')

# %%
course_str = '-'.join(courses)
print(course_str)
# Out:
# Art-history-physics-comp_sci-Art-Art-Art

# %%
courses.remove(['Ant','Edu'])

# %%
new_list = course_str.split('-')
print(new_list)
# Out:
# ['Art', 'history', 'physics', 'comp_sci', 'Art', 'Art', 'Art']
