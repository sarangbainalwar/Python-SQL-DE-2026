# %%
num = 3.15
print(type(num))
# Out:
# <class 'float'>

# %%
print(3//2)
print(3**3)
print(3%2)
# Out:
# 1
# 27
# 1

# %%
num = 1
num*=12
print(num)
# Out:
# 12

# %%
print(abs(-3.2))
# Out:
# 3.2

# %%
print(round(3.62,1))
# Out:
# 3.6

# %%
num_1 = 1
num_2 = 3

# %%
print(num_1 == num_2)
print(num_1 != num_2)
print(num_1 >= num_2)
# Out:
# False
# True
# False

# %%
num_1 = '100'
num_2 = '200'
print(num_1+num_2)
# Out:
# 100200

# %%
num_1 = int(num_1)
num_2 = int(num_2)
print(num_1 + num_2)
# Out:
# 300
