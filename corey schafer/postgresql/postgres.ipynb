# %%
import psycopg2

# %%
conn = psycopg2.connect(
    host="localhost",
    database="de_company_db",
    user="postgres",
    password="Sarang@123",
    port="5432"
)

print("connect successful")
# Out:
# connect successful

# %%
conn.rollback()

# %%
cursor = conn.cursor()

# %%
query = """select * from employees;"""

cursor.execute(query)

# %%
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'Rahul', 'IT', Decimal('60000'))
# (2, 'Priya', 'HR', Decimal('55000'))
# (3, 'Amit', 'Finance', Decimal('70000'))
# (4, 'Sneha', 'IT', Decimal('80000'))
# (5, 'Neha', 'Marketing', Decimal('65000'))

# %%
row_net = cursor.fetchone()

print(row)

rows = cursor.fetchmany(2)
print(rows)
# Out:
# None
# []

# %%
query = """
select * from employees
where department='IT';
"""

cursor.execute(query)

# %%
rows=cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'Rahul', 'IT', Decimal('60000'))
# (4, 'Sneha', 'IT', Decimal('80000'))

# %%
query = """
INSERT INTO employees
VALUES
(5,'Neha','Marketing',65000)
"""

cursor.execute(query)
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# Cell In[23], line 7
#       3 VALUES
#       4 (5,'Neha','Marketing',65000)
#       5 """
#       6
# ----> 7 cursor.execute(query)
#       8 conn.commit()
#
# UniqueViolation: duplicate key value violates unique constraint "employees_pkey"
# DETAIL:  Key (employee_id)=(5) already exists.

# %%
conn.commit()
