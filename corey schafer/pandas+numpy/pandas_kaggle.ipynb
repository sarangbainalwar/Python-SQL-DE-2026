# %%
import pandas as pd
import numpy as np

# %%
my_series = pd.Series(data=[1,2,3,4],index=['a','b','c','d'])
my_series
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
my_dict = {"x":2,"a":5,"b":4,"c":8}
my_series2 = pd.Series(my_dict)
my_series2
# Out:
# x    2
# a    5
# b    4
# c    8
# dtype: int64

# %%
print(my_series["a"])
# Out:
# 1

# %%
print(my_series2.iloc[0])
# Out:
# 2

# %%
my_series[1:3]
# Out:
# b    2
# c    3
# dtype: int64

# %%
my_series + my_series
# Out:
# a    2
# b    4
# c    6
# d    8
# dtype: int64

# %%
my_series + my_series2
# Out:
# a     6.0
# b     6.0
# c    11.0
# d     NaN
# x     NaN
# dtype: float64

# %%
print(np.mean(my_series))
print(np.mean(my_series2))
# Out:
# 2.5
# 4.75

# %%
my_dict = {"name":["Joe","Bob","Frans"],
           "age":np.array([10,15,20]),
           "weight":(75,123,239),
           "height":pd.Series([4.5,6.7,6.6],
                              index = ["joe","bob","frans"]),
           "siblings": 1,
           "gender":"M"}

df = pd.DataFrame(my_dict)
df
# Out:
#         name  age  weight  height  siblings gender
# joe      Joe   10      75     4.5         1      M
# bob      Bob   15     123     6.7         1      M
# frans  Frans   20     239     6.6         1      M

# %%
df2 = pd.DataFrame(my_dict,index = my_dict["name"])
df2
# Out:
#         name  age  weight  height  siblings gender
# Joe      Joe   10      75     NaN         1      M
# Bob      Bob   15     123     NaN         1      M
# Frans  Frans   20     239     NaN         1      M

# %%
df2["weight"]
# Out:
# Joe       75
# Bob      123
# Frans    239
# Name: weight, dtype: int64

# %%
df2.weight
# Out:
# Joe       75
# Bob      123
# Frans    239
# Name: weight, dtype: int64

# %%
del df2['name']

# %%
df2["IQ"] = [120,123,334]
df2
# Out:
#        age  weight  height  siblings gender   IQ
# Joe     10      75     NaN         1      M  120
# Bob     15     123     NaN         1      M  123
# Frans   20     239     NaN         1      M  334

# %%
df2["married"] = False
df2
# Out:
#        age  weight  height  siblings gender   IQ  married
# Joe     10      75     NaN         1      M  120    False
# Bob     15     123     NaN         1      M  123    False
# Frans   20     239     NaN         1      M  334    False

# %%
df2["College"] = pd.Series(["harvard"],index = ["Joe"])
df2
# Out:
#        age  weight  height  siblings gender   IQ  married  College
# Joe     10      75     NaN         1      M  120    False  harvard
# Bob     15     123     NaN         1      M  123    False      NaN
# Frans   20     239     NaN         1      M  334    False      NaN

# %%
df2.loc["Joe"]
# Out:
# age              10
# weight           75
# height          NaN
# siblings          1
# gender            M
# IQ              120
# married       False
# College     harvard
# Name: Joe, dtype: object

# %%
df2.loc["Joe","IQ"]
# Out:
# np.int64(120)

# %%
df2.loc["Joe":"Bob","IQ":"College"]
# Out:
#       IQ  married  College
# Joe  120    False  harvard
# Bob  123    False      NaN

# %%
df2.iloc[0]
# Out:
#      age  weight  height  siblings gender   IQ  married  College
# Joe   10      75     NaN         1      M  120    False  harvard
# Bob   15     123     NaN         1      M  123    False      NaN

# %%
df2.iloc[0:2,5:8]
# Out:
#       IQ  married  College
# Joe  120    False  harvard
# Bob  123    False      NaN

# %%
boolean_index = [False,True,True]

df2[boolean_index]
# Out:
#        age  weight  height  siblings gender   IQ  married College
# Bob     15     123     NaN         1      M  123    False     NaN
# Frans   20     239     NaN         1      M  334    False     NaN

# %%
boolean_index = df2["age"] > 12
df2[boolean_index]
# Out:
#        age  weight  height  siblings gender   IQ  married College
# Bob     15     123     NaN         1      M  123    False     NaN
# Frans   20     239     NaN         1      M  334    False     NaN

# %%
df2[df2["age"] > 12]
# Out:
#        age  weight  height  siblings gender   IQ  married College
# Bob     15     123     NaN         1      M  123    False     NaN
# Frans   20     239     NaN         1      M  334    False     NaN
