# %%
l = [5,46,64646,64,9,999,22222]

print(max(l))
print(min(l))
# Out:
# 64646
# 5

# %%
d={}
for i in l:
    if i in d:
        d[i]+=1
    else:
        d[i] = 1
        
d
# Out:
# {5: 1, 46: 1, 64646: 1, 64: 1, 9: 1, 999: 1, 22222: 1}
