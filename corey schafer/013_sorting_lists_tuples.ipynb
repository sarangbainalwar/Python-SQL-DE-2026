# %%
li = [5,8,7,6,9,1,3,4,2]

# %%
s_li = sorted(li,reverse=True)
print(s_li)
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
print(li)
print(li.sort(reverse=True))
print(li)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# None
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
tup=(5,8,7,6,9,1,3,4,2)
s_tup = sorted(tup,reverse=True)
print(s_tup)
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
dict = {'name':'Corey','job':'Instructor','age':47,'os':'win'}

# %%
s_di = sorted(dict)
print(s_di)
# Out:
# ['age', 'job', 'name', 'os']

# %%
li=[-6,-5,-4,1,2,3]
s_li = sorted(li,key=abs)
print(s_li)
# Out:
# [1, 2, 3, -4, -5, -6]
