# %%
country = 'india'
name='sarang'

# %%
letter = 'my name is {} and i am from {}'.format(name,country)
print(letter)
# Out:
# my name is sarang and i am from india

# %%
print(f'my name is {name} and i am from {country}')
# Out:
# my name is sarang and i am from india

# %%
price = 49.899999

# %%
txt = f"for only {price:.2f} dollars!"
print(txt)
# Out:
# for only 49.90 dollars!

# %%
print(f'{2*30}')
# Out:
# 60
