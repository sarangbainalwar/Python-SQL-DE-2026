# %%
import datetime

# %%
d = datetime.date(2016,7,24)
print(d)
# Out:
# 2016-07-24

# %%
today = datetime.date.today()
print(today)
print(today.day)
print(today.weekday())
print(today.isoweekday())
# Out:
# 2026-05-15
# 15
# 4
# 5

# %%
tdelta=datetime.timedelta(days=7)

# %%
print(today+tdelta)
print(today-tdelta)
# Out:
# 2026-05-22
# 2026-05-08

# %%
# date2=deta1+timedelta
#timedelta=date1+date2
bday=datetime.date(2026,5,23)
till_bday=bday-today
print(till_bday.total_seconds())
# Out:
# 691200.0

# %%
t=datetime.datetime(2026,5,23,12,30,45,100000)
print(t.year)
# Out:
# 2026

# %%
print(t+tdelta)
# Out:
# 2026-05-30 12:30:45.100000

# %%
dt_today=datetime.datetime.today()
dt_now=datetime.datetime.now()
dt_utcnow=datetime.datetime.now(datetime.UTC)

# %%
print(dt_today)
print(dt_now)
print(dt_utcnow)
# Out:
# 2026-05-15 17:04:35.308365
# 2026-05-15 17:04:35.308506
# 2026-05-15 11:34:35.308580+00:00
