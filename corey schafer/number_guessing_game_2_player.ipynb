# %%
import random

# %%
print("Welcome to the Number Guessing Game!")
print("Enter the number of players (1 or 2). In 1 player mode, you will be playing against the computer. In 2 player mode, you will be playing against another person.")
players = int(input("Number of players: "))
# Out:
# Welcome to the Number Guessing Game!
# Enter the number of players (1 or 2). In 1 player mode, you will be playing against the computer. In 2 player mode, you will be playing against another person.
