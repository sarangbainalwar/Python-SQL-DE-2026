# %%
with open("02_integers_float.ipynb","r") as file:
    line = file.read()
    print(line)
    print(f"jebjfbj {file.readlines}")
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": 3,
#    "id": "3e1a3e53",
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "<class 'float'>\n"
#      ]
#     }
#    ],
#    "source": [
#     "num = 3.15\n",
#     "print(type(num))"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 7,
#    "id": "4d8f2171",
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "1\n",
#       "27\n",
#       "1\n"
#      ]
#     }
#    ],
#    "source": [
#     "print(3//2)\n",
#     "print(3**3)\n",
#     "print(3%2)"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 11,
#    "id": "6bdedecd",
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "12\n"
#      ]
#     }
#    ],
#    "source": [
# ...

# %%
print(file.readline())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 print(file.readline())
#
# ValueError: I/O operation on closed file.
