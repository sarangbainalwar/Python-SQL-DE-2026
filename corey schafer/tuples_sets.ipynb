# %%
# creating tuples
my_tup = (1,2,3)

# %%
print(my_tup)
print(type(my_tup))
# creating a tuple with one element
my_tup2 = (4,)
print(my_tup2)
print(type(my_tup2))
# Out:
# (1, 2, 3)
# <class 'tuple'>
# (4,)
# <class 'tuple'>

# %%
# tuple unpacking is the process of assigning the elements of a tuple to variables in a single statement. This is done by using the same number of variables on the left side of the assignment operator as there are elements in the tuple on the right side.

a,b,c = my_tup
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
# length of a tuple
print(len(my_tup))
# Out:
# 3

# %%
print(dir(my_tup))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'count', 'index']

# %%
my_tup[2]
my_tup[0:2]
my_tup.count(6)
# Out:
# 0

# %%
# when to use tuples vs lists
# tuples are immutable, meaning that they cannot be changed after they are created. This makes them faster than lists, which are mutable. If you have a collection of data that you know will not change, then you should use a tuple. If you have a collection of data that you know will change, then you should use a list.

# %%
# quick syntax for list, set, tuple, dictionary
my_list = [1,2,3]
my_tuple = (1,2,3)
my_set = {1,2,3}
my_dict = {'a':1, 'b':2, 'c':3}

# %%
# creating sets
my_set = {1,2,3}
print(my_set)
# Out:
# {1, 2, 3}

# %%
# set operations - union, intersection, difference, symmetric difference
set1 = {1,2,3}
set2 = {3,4,5}
print(set1, set2)
print(set1.union(set2))
print(set1.intersection(set2))
print(set1.difference(set2))
print(set2.difference(set1))
print(set1.symmetric_difference(set2))
# Out:
# {1, 2, 3} {3, 4, 5}
# {1, 2, 3, 4, 5}
# {3}
# {1, 2}
# {4, 5}
# {1, 2, 4, 5}

# %%
# set add and remove
my_set.add(4)
print(my_set)
my_set.remove(1)
print(my_set)
# Out:
# {1, 3, 4}
# {3, 4}

# %%
# do sets store duplicates?
my_set.add(2)
print(my_set)
# Out:
# {2, 3, 4}

# %%
# set practice problems
# 1. Create a set of the first 5 prime numbers.
prime_set = {2,3,5,7,11}
print(prime_set)
# 2. Create a set of the first 5 Fibonacci numbers.
fib_set = {0,1,1,2,3}
# Out:
# {2, 3, 5, 7, 11}
